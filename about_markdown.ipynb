# %% [markdown]
# # ------------------- Raw text -------------------

# %% [markdown]
# **Syntax**
#
# Today is a cloudy day and a good day to practice Markdown.
#
# &darr;
#
# **Output**
#
# Today is a cloudy day and a good day to practice Markdown.

# %% [markdown]
# ___
# **Syntax**
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Today is a cloudy day and a good day to practice Markdown.
#
# &darr;
#
# **Output (Code Blocks)**
#
#     Today is a cloudy day and a good day to practice Markdown.

# %% [markdown]
# ___
# **Syntax**
#
# \>Today is a cloudy day and a good day to practice Markdown.
#
# &darr;
#
# **Output (Quote)**
#
# >Today is a cloudy day and a good day to practice Markdown.

# %% [markdown]
# # ------------------- HTML tag -------------------
#
# It respresents the root of an HTML document.

# %% [markdown]
# **Syntax**
#
# \<div>
#
# &darr;
#
# **Output**
#
# <div>

# %% [markdown]
# ___
#
# **Syntax**
#
# \\\<div>
#
# &darr;
#
# **Output**
#
# \<div>

# %% [markdown]
# ___
#
# **Syntax**
#
# \&lt;
#
# &darr;
#
# **Output**
#
# &lt;

# %% [markdown]
# ___
#
# **Syntax**
#
# \&lt;div>
#
# &darr;
#
# **Output**
#
# &lt;div>

# %% [markdown]
# ___
#
# **Syntax**
#
# \\\\\<div>
#
# &darr;
#
# **Output**
#
# \\<div>

# %% [markdown]
# ___
#
# **Syntax**
#
# <div\\>
#
# or
#
# \\<div\\>
#
# &darr;
#
# **Output**
#
# <div\>

# %% [markdown]
# # ------------------- Other HTML -------------------

# %% [markdown]
# ___
#
# **Syntax**
#
# \<div>
#
# \<p>Today is a cloudy day and a good day to practice Markdown.\</p>
#
# \</div>
#
# &darr;
#
# **Output**
#
# <div>
#     <p>Today is a cloudy day and a good day to practice Markdown.</p>
# </div>

# %% [markdown]
# ___
#
# **Syntax**
#
# \\<div\>
#
# \\\<p\>Today is a cloudy day and a good day to practice Markdown.\\\</p\>
#
# \\</div\>
#
# &darr;
#
# **Output**
#
# \<div>
#
# \<p>Today is a cloudy day and a good day to practice Markdown.\</p>
#
# \</div>

# %% [markdown]
# ___
#
# **Syntax**
#
# \\<div\>
#
# \<p>Today is a cloudy day and a good day to practice Markdown.\</p>
#
# \\</div\>
#
# &darr;
#
# **Output**
#
# \\<div\>
#
# <p>Today is a cloudy day and a good day to practice Markdown.</p>
#
# \\</div\>

# %% [markdown]
# # ------------------- IMAGE -------------------

# %% [markdown]
# ## Raw image
#
# **Syntax**
#
# \!\[image.png](attachment:image.png)
#
# &darr;
#
# **Output**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Resized image
#
# **Syntax**
#
# \<div>
#
# \<img src="attachment:image.png" width="250" />
#
# \</div>
#
# &darr;
#
# **Output**
#
# <div>
# <img src="attachment:image.png" width="250" />
# </div>

# %% [markdown]
# On a side note, the image was originally printed locally but not shown in GitHub, found a solution on https://github.com/jupyter/notebook/issues/3278.
#
# - Before
#
# > \<div><br/>
# > \<img src="attachment:image.png" width="250" ><br/>
# > \</div>
#
#
#
# - After
#
# > \<div><br/>
# > \<img src="attachment:image.png" width="250" /><br/>
# > \</div>

# %% [markdown]
# ___
# **Syntax**
#
#
# \<img src="attachment:image.png" width="250">
#
# &darr;
#
# **Output**

# %% [markdown]
# <img src="attachment:image.png" width="250">
